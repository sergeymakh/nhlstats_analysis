# %%
import requests
import pandas as pd

# %%
r = requests.get("https://api-web.nhle.com/v1/gamecenter/2024020177/boxscore")
r.json()
# df = pd.DataFrame.from_dict(r.json())
# df.head()
# Out:
# {'id': 2024020177,
#  'season': 20242025,
#  'gameType': 2,
#  'limitedScoring': False,
#  'gameDate': '2024-11-02',
#  'venue': {'default': 'Capital One Arena'},
#  'venueLocation': {'default': 'Washington'},
#  'startTimeUTC': '2024-11-02T21:00:00Z',
#  'easternUTCOffset': '-04:00',
#  'venueUTCOffset': '-04:00',
#  'tvBroadcasts': [{'id': 565,
#    'market': 'A',
#    'countryCode': 'US',
#    'network': 'FDSNOH',
#    'sequenceNumber': 276},
#   {'id': 517,
#    'market': 'H',
#    'countryCode': 'US',
#    'network': 'MNMT',
#    'sequenceNumber': 387}],
#  'gameState': 'OFF',
#  'gameScheduleState': 'OK',
#  'periodDescriptor': {'number': 3,
#   'periodType': 'REG',
#   'maxRegulationPeriods': 3},
#  'regPeriods': 3,
#  'awayTeam': {'id': 29,
#   'name': {'default': 'Blue Jackets'},
#   'abbrev': 'CBJ',
#   'score': 2,
#   'sog': 36,
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/CBJ_light.svg',
#   'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/CBJ_dark.svg',
#   'placeName': {'default': 'Columbus'},
#   'placeNameWithPreposition': {'default': 'Columbus', 'fr': 'de Columbus'}},
#  'homeTeam': {'id': 15,
#   'name': {'default': 'Capitals'},
#   'abbrev': 'WSH',
#   'score': 7,
#   'sog': 22,
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/WSH_secondary_light.svg',
#   'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/WSH_secondary_dark.svg',
#   'placeName': {'default': 'Washington'},
#   'placeNameWithPreposition': {'default': 'Washington',
#    'fr': 'de Washington'}},
#  'clock': {'timeRemaining': '00:00',
#   'secondsRemaining': 0,
#   'running': False,
#   'inIntermission': False},
#  'playerByGameStats': {'awayTeam': {'forwards': [{'playerId': 8482705,
#      'sweaterNumber': 4,
#      'name': {'default': 'C. Sillinger'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -4,
#      'pim': 0,
#      'hits': 2,
#      'powerPlayGoals': 0,
#      'sog': 1,
#      'faceoffWinningPctg': 1.0,
#      'toi': '18:15',
#      'blockedShots': 0,
#      'shifts': 20,
#      'giveaways': 2,
#      'takeaways': 1},
#     {'playerId': 8476374,
#      'sweaterNumber': 7,
#      'name': {'default': 'S. Kuraly'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -1,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'sog': 1,
#      'faceoffWinningPctg': 0.846154,
#      'toi': '14:25',
#      'blockedShots': 0,
#      'shifts': 16,
#      'giveaways': 1,
#      'takeaways': 2},
#     {'playerId': 8481716,
#      'sweaterNumber': 10,
#      'name': {'default': 'D. Voronkov'},
#      'position': 'L',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -1,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'sog': 2,
#      'faceoffWinningPctg': 0.0,
#      'toi': '13:47',
#      'blockedShots': 0,
#      'shifts': 18,
#      'giveaways': 0,
#      'takeaways': 0},
#     {'playerId': 8479941,
#      'sweaterNumber': 17,
#      'name': {'default': 'J. Danforth'},
#      'position': 'R',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -2,
#      'pim': 0,
#      'hits': 4,
#      'powerPlayGoals': 0,
#      'sog': 1,
#      'faceoffWinningPctg': 0.5,
#      'toi': '13:49',
#      'blockedShots': 1,
#      'shifts': 19,
#      'giveaways': 0,
#      'takeaways': 0},
#     {'playerId': 8484166,
#      'sweaterNumber': 19,
#      'name': {'default': 'A. Fantilli'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 1,
#      'points': 1,
#      'plusMinus': -1,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'sog': 4,
#      'faceoffWinningPctg': 0.578947,
#      'toi': '16:34',
#      'blockedShots': 0,
#      'shifts': 19,
#      'giveaways': 1,
#      'takeaways': 0},
#     {'playerId': 8477497,
#      'sweaterNumber': 23,
#      'name': {'default': 'S. Monahan'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 1,
#      'points': 1,
#      'plusMinus': -1,
#      'pim': 2,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'sog': 2,
#      'faceoffWinningPctg': 0.5,
#      'toi': '16:32',
#      'blockedShots': 1,
#      'shifts': 20,
#      'giveaways': 1,
#      'takeaways': 1},
#     {'playerId': 8479671,
#      'sweaterNumber': 24,
#      'name': {'default': 'M. Olivier'},
#      'position': 'R',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -2,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'sog': 3,
#      'faceoffWinningPctg': 0.0,
#      'toi': '12:52',
#      'blockedShots': 0,
#      'shifts': 17,
#      'giveaways': 0,
#      'takeaways': 1},
#     {'playerId': 8479944,
#      'sweaterNumber': 27,
#      'name': {'default': 'Z. Aston-Reese'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 1,
#      'points': 1,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'sog': 1,
#      'faceoffWinningPctg': 0.0,
#      'toi': '14:37',
#      'blockedShots': 1,
#      'shifts': 16,
#      'giveaways': 0,
#      'takeaways': 0},
#     {'playerId': 8482475,
#      'sweaterNumber': 59,
#      'name': {'default': 'Y. Chinakhov'},
#      'position': 'R',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 1,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'sog': 4,
#      'faceoffWinningPctg': 0.0,
#      'toi': '16:25',
#      'blockedShots': 0,
#      'shifts': 20,
#      'giveaways': 0,
#      'takeaways': 0},
#     {'playerId': 8478099,
#      'sweaterNumber': 62,
#      'name': {'default': 'K. Labanc'},
#      'position': 'R',
#      'goals': 1,
#      'assists': 0,
#      'points': 1,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'sog': 3,
#      'faceoffWinningPctg': 0.0,
#      'toi': '14:20',
#      'blockedShots': 0,
#      'shifts': 16,
#      'giveaways': 0,
#      'takeaways': 0},
#     {'playerId': 8482451,
#      'sweaterNumber': 82,
#      'name': {'default': 'M. Pyyhtia'},
#      'position': 'L',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -2,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'sog': 0,
#      'faceoffWinningPctg': 0.0,
#      'toi': '12:28',
#      'blockedShots': 0,
#      'shifts': 17,
#      'giveaways': 0,
#      'takeaways': 0},
#     {'playerId': 8480893,
#      'sweaterNumber': 86,
#      'name': {'default': 'K. Marchenko'},
#      'position': 'R',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -2,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'sog': 2,
#      'faceoffWinningPctg': 0.0,
#      'toi': '16:51',
#      'blockedShots': 0,
#      'shifts': 20,
#      'giveaways': 2,
#      'takeaways': 1}],
#    'defense': [{'playerId': 8481161,
#      'sweaterNumber': 2,
#      'name': {'default': 'J. Christiansen'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -1,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'sog': 1,
#      'faceoffWinningPctg': 0.0,
#      'toi': '16:17',
#      'blockedShots': 1,
#      'shifts': 17,
#      'giveaways': 1,
#      'takeaways': 1},
#     {'playerId': 8471677,
#      'sweaterNumber': 3,
#      'name': {'default': 'J. Johnson'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -2,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'sog': 1,
#      'faceoffWinningPctg': 0.0,
#      'toi': '16:08',
#      'blockedShots': 1,
#      'shifts': 19,
#      'giveaways': 1,
#      'takeaways': 0},
#     {'playerId': 8478460,
#      'sweaterNumber': 8,
#      'name': {'default': 'Z. Werenski'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -2,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'sog': 4,
#      'faceoffWinningPctg': 0.0,
#      'toi': '25:06',
#      'blockedShots': 2,
#      'shifts': 23,
#      'giveaways': 1,
#      'takeaways': 0},
#     {'playerId': 8478500,
#      'sweaterNumber': 9,
#      'name': {'default': 'I. Provorov'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -2,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'sog': 1,
#      'faceoffWinningPctg': 0.0,
#      'toi': '24:32',
#      'blockedShots': 1,
#      'shifts': 25,
#      'giveaways': 1,
#      'takeaways': 2},
#     {'playerId': 8483460,
#      'sweaterNumber': 55,
#      'name': {'default': 'D. Jiricek'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': -2,
#      'pim': 0,
#      'hits': 2,
#      'powerPlayGoals': 0,
#      'sog': 2,
#      'faceoffWinningPctg': 0.0,
#      'toi': '17:05',
#      'blockedShots': 1,
#      'shifts': 17,
#      'giveaways': 1,
#      'takeaways': 1},
#     {'playerId': 8476923,
#      'sweaterNumber': 78,
#      'name': {'default': 'D. Severson'},
#      'position': 'D',
#      'goals': 1,
#      'assists': 0,
#      'points': 1,
#      'plusMinus': -1,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'sog': 3,
#      'faceoffWinningPctg': 0.0,
#      'toi': '17:57',
#      'blockedShots': 1,
#      'shifts': 20,
#      'giveaways': 1,
#      'takeaways': 0}],
#    'goalies': [{'playerId': 8480193,
#      'sweaterNumber': 40,
#      'name': {'default': 'D. Tarasov'},
#      'position': 'G',
#      'evenStrengthShotsAgainst': '15/22',
#      'powerPlayShotsAgainst': '0/0',
#      'shorthandedShotsAgainst': '0/0',
#      'saveShotsAgainst': '15/22',
#      'savePctg': 0.681818,
#      'evenStrengthGoalsAgainst': 7,
#      'powerPlayGoalsAgainst': 0,
#      'shorthandedGoalsAgainst': 0,
#      'pim': 0,
#      'goalsAgainst': 7,
#      'toi': '60:00',
#      'starter': True,
#      'decision': 'L',
#      'shotsAgainst': 22,
#      'saves': 15},
#     {'playerId': 8478007,
#      'sweaterNumber': 90,
#      'name': {'default': 'E. Merzlikins'},
#      'position': 'G',
#      'evenStrengthShotsAgainst': '0/0',
#      'powerPlayShotsAgainst': '0/0',
#      'shorthandedShotsAgainst': '0/0',
#      'saveShotsAgainst': '0/0',
#      'evenStrengthGoalsAgainst': 0,
#      'powerPlayGoalsAgainst': 0,
#      'shorthandedGoalsAgainst': 0,
#      'pim': 0,
#      'goalsAgainst': 0,
#      'toi': '00:00',
#      'starter': False,
#      'shotsAgainst': 0,
#      'saves': 0}]},
#   'homeTeam': {'forwards': [{'playerId': 8471214,
#      'sweaterNumber': 8,
#      'name': {'default': 'A. Ovechkin',
#       'cs': 'A. Ovečkin',
#       'fi': 'A. Ovetshkin',
#       'sk': 'A. Ovečkin'},
#      'position': 'L',
#      'goals': 1,
#      'assists': 2,
#      'points': 3,
#      'plusMinus': 4,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'sog': 4,
#      'faceoffWinningPctg': 0.0,
#      'toi': '13:35',
#      'blockedShots': 0,
#      'shifts': 19,
#      'giveaways': 2,
#      'takeaways': 1},
#     {'playerId': 8477944,
#      'sweaterNumber': 13,
#      'name': {'default': 'J. Vrana', 'cs': 'J. Vrána', 'sk': 'J. Vrána'},
#      'position': 'L',
#      'goals': 0,
#      'assists': 1,
#      'points': 1,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'sog': 2,
#      'faceoffWinningPctg': 0.0,
#      'toi': '14:03',
#      'blockedShots': 1,
#      'shifts': 18,
#      'giveaways': 0,
#      'takeaways': 0},
#     {'playerId': 8479390,
#      'sweaterNumber': 16,
#      'name': {'default': 'T. Raddysh'},
#      'position': 'R',
#      'goals': 0,
#      'assists': 1,
#      'points': 1,
#      'plusMinus': 2,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'sog': 3,
#      'faceoffWinningPctg': 1.0,
#      'toi': '13:19',
#      'blockedShots': 0,
#      'shifts': 19,
#      'giveaways': 1,
#      'takeaways': 1},
#     {'playerId': 8478440,
#      'sweaterNumber': 17,
#      'name': {'default': 'D. Strome'},
#      'position': 'C',
#      'goals': 1,
#      'assists': 2,
#      'points': 3,
#      'plusMinus': 4,
#      'pim': 2,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'sog': 2,
#      'faceoffWinningPctg': 0.444444,
#      'toi': '14:47',
#      'blockedShots': 0,
#      'shifts': 19,
#      'giveaways': 1,
#      'takeaways': 0},
#     {'playerId': 8481656,
#      'sweaterNumber': 21,
#      'name': {'default': 'A. Protas'},
#      'position': 'C',
#      'goals': 1,
#      'assists': 1,
#      'points': 2,
#      'plusMinus': 1,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'sog': 1,
#      'faceoffWinningPctg': 0.0,
#      'toi': '15:49',
#      'blockedShots': 0,
#      'shifts': 21,
#      'giveaways': 3,
#      'takeaways': 0},
#     {'playerId': 8479520,
#      'sweaterNumber': 22,
#      'name': {'default': 'B. Duhaime'},
#      'position': 'R',
#      'goals': 0,
#      'assists': 1,
#      'points': 1,
#      'plusMinus': 1,
#      'pim': 2,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'sog': 0,
#      'faceoffWinningPctg': 1.0,
#      'toi': '13:56',
#      'blockedShots': 1,
#      'shifts': 23,
#      'giveaways': 0,
#      'takeaways': 0},
#     {'playerId': 8481580,
#      'sweaterNumber': 24,
#      'name': {'default': 'C. McMichael'},
#      'position': 'C',
#      'goals': 2,
#      'assists': 0,
#      'points': 2,
#      'plusMinus': 1,
#      'pim': 2,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'sog': 4,
#      'faceoffWinningPctg': 0.0,
#      'toi': '15:56',
#      'blockedShots': 0,
#      'shifts': 19,
#      'giveaways': 1,
#      'takeaways': 0},
#     {'playerId': 8475343,
#      'sweaterNumber': 26,
#      'name': {'default': 'N. Dowd'},
#      'position': 'C',
#      'goals': 1,
#      'assists': 0,
#      'points': 1,
#      'plusMinus': 1,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'sog': 2,
#      'faceoffWinningPctg': 0.428571,
#      'toi': '14:24',
#      'blockedShots': 1,
#      'shifts': 21,
#      'giveaways': 0,
#      'takeaways': 1},
#     {'playerId': 8482148,
#      'sweaterNumber': 29,
#      'name': {'default': 'H. Lapierre'},
#      'position': 'C',
#      'goals': 0,
#      'assists': 1,
#      'points': 1,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'sog': 1,
#      'faceoffWinningPctg': 0.285714,
#      'toi': '14:33',
#      'blockedShots': 2,
#      'shifts': 18,
#      'giveaways': 0,
#      'takeaways': 1},
#     {'playerId': 8476880,
#      'sweaterNumber': 43,
#      'name': {'default': 'T. Wilson'},
#      'position': 'R',
#      'goals': 0,
#      'assists': 1,
#      'points': 1,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 3,
#      'powerPlayGoals': 0,
#      'sog': 1,
#      'faceoffWinningPctg': 0.0,
#      'toi': '15:49',
#      'blockedShots': 4,
#      'shifts': 19,
#      'giveaways': 1,
#      'takeaways': 0},
#     {'playerId': 8479400,
#      'sweaterNumber': 80,
#      'name': {'default': 'P. Dubois'},
#      'position': 'L',
#      'goals': 0,
#      'assists': 1,
#      'points': 1,
#      'plusMinus': 0,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'sog': 0,
#      'faceoffWinningPctg': 0.363636,
#      'toi': '14:27',
#      'blockedShots': 2,
#      'shifts': 18,
#      'giveaways': 1,
#      'takeaways': 0},
#     {'playerId': 8478233,
#      'sweaterNumber': 88,
#      'name': {'default': 'A. Mangiapane'},
#      'position': 'L',
#      'goals': 1,
#      'assists': 0,
#      'points': 1,
#      'plusMinus': 1,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'sog': 2,
#      'faceoffWinningPctg': 0.0,
#      'toi': '13:55',
#      'blockedShots': 0,
#      'shifts': 19,
#      'giveaways': 2,
#      'takeaways': 0}],
#    'defense': [{'playerId': 8480823,
#      'sweaterNumber': 27,
#      'name': {'default': 'A. Alexeyev',
#       'cs': 'A. Alexejev',
#       'sk': 'A. Alexejev'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 2,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'sog': 0,
#      'faceoffWinningPctg': 0.0,
#      'toi': '16:44',
#      'blockedShots': 4,
#      'shifts': 22,
#      'giveaways': 0,
#      'takeaways': 0},
#     {'playerId': 8480873,
#      'sweaterNumber': 38,
#      'name': {'default': 'R. Sandin'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 1,
#      'points': 1,
#      'plusMinus': 2,
#      'pim': 0,
#      'hits': 1,
#      'powerPlayGoals': 0,
#      'sog': 0,
#      'faceoffWinningPctg': 0.0,
#      'toi': '20:37',
#      'blockedShots': 4,
#      'shifts': 22,
#      'giveaways': 0,
#      'takeaways': 0},
#     {'playerId': 8480796,
#      'sweaterNumber': 42,
#      'name': {'default': 'M. Fehervary',
#       'cs': 'M. Fehérváry',
#       'sk': 'M. Fehérváry'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 1,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'sog': 0,
#      'faceoffWinningPctg': 0.0,
#      'toi': '22:02',
#      'blockedShots': 5,
#      'shifts': 24,
#      'giveaways': 2,
#      'takeaways': 0},
#     {'playerId': 8475795,
#      'sweaterNumber': 52,
#      'name': {'default': 'D. McIlrath'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 2,
#      'pim': 0,
#      'hits': 4,
#      'powerPlayGoals': 0,
#      'sog': 0,
#      'faceoffWinningPctg': 0.0,
#      'toi': '20:02',
#      'blockedShots': 2,
#      'shifts': 21,
#      'giveaways': 3,
#      'takeaways': 0},
#     {'playerId': 8477845,
#      'sweaterNumber': 57,
#      'name': {'default': 'T. van Riemsdyk'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 1,
#      'points': 1,
#      'plusMinus': 2,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'sog': 0,
#      'faceoffWinningPctg': 0.0,
#      'toi': '18:42',
#      'blockedShots': 3,
#      'shifts': 23,
#      'giveaways': 4,
#      'takeaways': 0},
#     {'playerId': 8474590,
#      'sweaterNumber': 74,
#      'name': {'default': 'J. Carlson'},
#      'position': 'D',
#      'goals': 0,
#      'assists': 0,
#      'points': 0,
#      'plusMinus': 1,
#      'pim': 0,
#      'hits': 0,
#      'powerPlayGoals': 0,
#      'sog': 0,
#      'faceoffWinningPctg': 0.0,
#      'toi': '21:20',
#      'blockedShots': 1,
#      'shifts': 24,
#      'giveaways': 0,
#      'takeaways': 0}],
#    'goalies': [{'playerId': 8480313,
#      'sweaterNumber': 48,
#      'name': {'default': 'L. Thompson'},
#      'position': 'G',
#      'evenStrengthShotsAgainst': '26/28',
#      'powerPlayShotsAgainst': '8/8',
#      'shorthandedShotsAgainst': '0/0',
#      'saveShotsAgainst': '34/36',
#      'savePctg': 0.944444,
#      'evenStrengthGoalsAgainst': 2,
#      'powerPlayGoalsAgainst': 0,
#      'shorthandedGoalsAgainst': 0,
#      'pim': 0,
#      'goalsAgainst': 2,
#      'toi': '60:00',
#      'starter': True,
#      'decision': 'W',
#      'shotsAgainst': 36,
#      'saves': 34},
#     {'playerId': 8479292,
#      'sweaterNumber': 79,
#      'name': {'default': 'C. Lindgren'},
#      'position': 'G',
#      'evenStrengthShotsAgainst': '0/0',
#      'powerPlayShotsAgainst': '0/0',
#      'shorthandedShotsAgainst': '0/0',
#      'saveShotsAgainst': '0/0',
#      'evenStrengthGoalsAgainst': 0,
#      'powerPlayGoalsAgainst': 0,
#      'shorthandedGoalsAgainst': 0,
#      'pim': 0,
#      'goalsAgainst': 0,
#      'toi': '00:00',
#      'starter': False,
#      'shotsAgainst': 0,
#      'saves': 0}]}},
#  'summary': {},
#  'gameOutcome': {'lastPeriodType': 'REG'}}
